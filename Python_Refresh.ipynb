# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryanonit/AI_Analyst_Copilot/blob/AI_Analyst_Copilot/Python_Refresh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Python in Colab!")
# Out:
# Hello, Python in Colab!
